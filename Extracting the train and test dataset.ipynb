# %%
label_0 = []
label_1 = []
label_2 = []
label_3 = []
label_4 = []
label_5 = []
label_6 = []
label_7 = []
label_8 = []
label_9 = []

for i in df.index.values:
    
    if df['label'][i]==0:
        label_0.append(str(df['id'][i])+'.png')
        
    elif df['label'][i]==1:
        label_1.append(str(df['id'][i])+'.png')
        
    elif df['label'][i]==2:
        label_2.append(str(df['id'][i])+'.png')
        
    elif df['label'][i]==3:
        label_3.append(str(df['id'][i])+'.png')
        
    elif df['label'][i]==4:
        label_4.append(str(df['id'][i])+'.png')
        
    elif df['label'][i]==5:
        label_5.append(str(df['id'][i])+'.png')
        
    elif df['label'][i]==6:
        label_6.append(str(df['id'][i])+'.png')
        
    elif df['label'][i]==7:
        label_7.append(str(df['id'][i])+'.png')
    
    elif df['label'][i]==8:
        label_8.append(str(df['id'][i])+'.png')
    
    else:
        label_9.append(str(df['id'][i])+'.png')

# %% [markdown]
# ## Train Dataset

# %%
import os, shutil
folder_path = "C:\\Users\\Lenovo\\Downloads\\Fashion MNIST\\train\\train"

#folder_pth = 'D:\\Downloads\\Fashion MNIST\\train'

images = [f for f in os.listdir(folder_path) if os.path.isfile(os.path.join(folder_path, f))]

for image in images:
    
    if image in label_0:
        new_path = os.path.join(folder_path, 'label_0')

        if not os.path.exists(new_path):
            os.makedirs(new_path)
    
        old_image_path = os.path.join(folder_path, image)
        new_image_path = os.path.join(new_path, image)
        shutil.move(old_image_path, new_image_path)
        
    elif image in label_2:
        new_path = os.path.join(folder_path, 'label_2')

        if not os.path.exists(new_path):
            os.makedirs(new_path)
    
        old_image_path = os.path.join(folder_path, image)
        new_image_path = os.path.join(new_path, image)
        shutil.move(old_image_path, new_image_path)
        
    elif image in label_3:
        new_path = os.path.join(folder_path, 'label_3')

        if not os.path.exists(new_path):
            os.makedirs(new_path)
    
        old_image_path = os.path.join(folder_path, image)
        new_image_path = os.path.join(new_path, image)
        shutil.move(old_image_path, new_image_path)
        
    elif image in label_9:
        new_path = os.path.join(folder_path, 'label_9')

        if not os.path.exists(new_path):
            os.makedirs(new_path)
    
        old_image_path = os.path.join(folder_path, image)
        new_image_path = os.path.join(new_path, image)
        shutil.move(old_image_path, new_image_path)
        
    elif image in label_1:
        new_path = os.path.join(folder_path, 'label_1')

        if not os.path.exists(new_path):
            os.makedirs(new_path)
    
        old_image_path = os.path.join(folder_path, image)
        new_image_path = os.path.join(new_path, image)
        shutil.move(old_image_path, new_image_path)
        
    elif image in label_4:
        new_path = os.path.join(folder_path, 'label_4')

        if not os.path.exists(new_path):
            os.makedirs(new_path)
    
        old_image_path = os.path.join(folder_path, image)
        new_image_path = os.path.join(new_path, image)
        shutil.move(old_image_path, new_image_path)
        
    elif image in label_5:
        new_path = os.path.join(folder_path, 'label_5')

        if not os.path.exists(new_path):
            os.makedirs(new_path)
    
        old_image_path = os.path.join(folder_path, image)
        new_image_path = os.path.join(new_path, image)
        shutil.move(old_image_path, new_image_path)
        
    elif image in label_6:
        new_path = os.path.join(folder_path, 'label_6')

        if not os.path.exists(new_path):
            os.makedirs(new_path)
    
        old_image_path = os.path.join(folder_path, image)
        new_image_path = os.path.join(new_path, image)
        shutil.move(old_image_path, new_image_path)
        
    elif image in label_7:
        new_path = os.path.join(folder_path, 'label_7')

        if not os.path.exists(new_path):
            os.makedirs(new_path)
    
        old_image_path = os.path.join(folder_path, image)
        new_image_path = os.path.join(new_path, image)
        shutil.move(old_image_path, new_image_path)
    
    elif image in label_8:
        new_path = os.path.join(folder_path, 'label_8')

        if not os.path.exists(new_path):
            os.makedirs(new_path)
    
        old_image_path = os.path.join(folder_path, image)
        new_image_path = os.path.join(new_path, image)
        shutil.move(old_image_path, new_image_path)
         
        
    else:
        pass

# %% [markdown]
# ## Test Dataset

# %%
label_folders= ['label_0','label_1','label_2','label_3','label_4','label_5','label_6','label_7','label_8','label_9']

# %%
import shutil
import os
    
source_dir = "C:\\Users\\Lenovo\\Downloads\\Fashion MNIST\\train\\train"
target_dir = "C:\\Users\\Lenovo\\Downloads\\Fashion MNIST\\test_images"

for i in label_folders:
    target_path = os.path.join(target_dir, i)
    source_path = os.path.join(source_dir, i)

    images = [f for f in os.listdir(source_path) if os.path.isfile(os.path.join(source_path, f))]
    count = 0
    
    for image in images:
        new_path = os.path.join(target_path, i)

        if not os.path.exists(new_path):
            os.makedirs(new_path)
            
        if count <600:
       
            old_image_path = os.path.join(source_path, image)
            new_image_path = os.path.join(target_path, image)
            shutil.move(old_image_path, new_image_path)
            count += 1
